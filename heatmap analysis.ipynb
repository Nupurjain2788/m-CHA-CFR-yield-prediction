# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# create dataframe
df = pd.DataFrame({
    'substrate_1': ['S1', 'S1', 'S1', 'S1', 'S1', 'S1', 'S2', 'S2', 'S3', 'S3', 'S3', 'S4', 'S5', 'S6', 'S6', 'S7', 'S8', 'S8', 'S8', 'S9', 'S10', 'S11', 'S12', 'S13', 'S14', 'S15', 'S16', 'S16'],
    'c.p': ['alkene', 'PhI(TFA)$_2$', 'PhI(OAc)$_2$', 'alkyne', '(SiMe$_3$)$_2$', '(GeMe$_3$)$_2$', 'alkene', 'alkyne', 'alkene', 'PhI(TFA)$_2$', 'PhI(OAc)$_2$', 'alkene', 'alkyne', 'alkene', 'aryl', 'alkene', 'alkyne', 'Ar-BPin', 'alkene', 'alkene', 'alkene', 'alkene', 'alkene', 'alkene', 'alkene', 'alkene', 'Ar-BPin', 'alkene'],
    'no': [130, 15, 16, 14, 25, 4, 60, 19, 23, 7, 6, 34, 55, 39, 19, 60, 29, 23, 58, 25, 8, 55, 22, 29, 22, 21, 40, 8]
})

# define order of substrates and reaction types
substrate_order = ['S1', 'S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8', 'S9', 'S10', 'S11', 'S12', 'S13', 'S14', 'S15', 'S16']
reaction_order = ['alkene', 'PhI(TFA)$_2$', 'PhI(OAc)$_2$', 'alkyne', '(SiMe$_3$)$_2$', '(GeMe$_3$)$_2$', 'Ar-BPin']

# create matrix with desired order
matrix = df.pivot_table(index='substrate_1', columns='c.p', values='no', fill_value=0, aggfunc='sum')
matrix = matrix.reindex(substrate_order)
matrix = matrix[reaction_order]

# plot the heatmap with increased color saturation
sns.set(font_scale=1.2)
fig, ax = plt.subplots(figsize=(8, 6))
cmap = sns.light_palette("green", as_cmap=True, reverse=False)
sns.heatmap(matrix, annot=True, cmap=cmap, fmt='g', linewidths=0.5, cbar=False,
            cbar_kws={"label": "occurance"}, linewidth=2.5, linecolor='white', annot_kws={"fontsize": 14}) #, "fontweight": 'bold'})

# Set background color
#ax.set_facecolor('#8B0000')  # dark blue background color

ax.set_title('substrate vs coupling partner', pad=15, fontsize=14, color='black')
ax.set_xlabel('coupling partner', fontsize=14, color='black')
ax.set_ylabel('substrate catagory', fontsize=14, color='black')

# rotate y-axis by 90 degrees
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=12)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, fontsize=12)
# save the heatmap as a PNG file
fig.savefig('substrate vs coupling partner.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# create dataframe
df = pd.DataFrame({
    'substrate1': ['S1', 'S1', 'S2', 'S2', 'S3', 'S4', 'S5', 'S5', 'S6', 'S7', 'S8', 'S8', 'S9', 'S10', 'S11', 'S12', 'S13', 'S14', 'S15', 'S16'],
    'catalyst': ['Pd(OAc)$_2$', '[Rh(COD)Cl]$_2$', 'Pd(OAc)$_2$', '[Rh(COD)Cl]$_2$', 'Pd(OAc)$_2$', 'Pd(OAc)$_2$', 'Pd(OAc)$_2$', '[Rh(COD)Cl]$_2$', 'Pd(OAc)$_2$', 'Pd(OAc)$_2$', 'Pd(OAc)$_2$', '[Rhcp*Cl$_2$]$_2$', 'Pd(OAc)$_2$', 'Pd(OAc)$_2$', 'Pd(OAc)$_2$', 'Pd(OAc)$_2$', 'Pd(Opiv)$_2$', 'Pd(OAc)$_2$', '[Rhcp*Cl$_2$]$_2$', 'Pd(OAc)$_2$'],
    'no.': [133, 71, 60, 19, 36, 34, 45, 10, 58, 60, 54, 56, 25, 8, 55, 22, 29, 22, 21, 48]
})

# define order of substrates and catalysts
substrate_order = ['S1', 'S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8', 'S9', 'S10', 'S11', 'S12', 'S13', 'S14', 'S15', 'S16']
catalyst_order = ['Pd(OAc)$_2$', '[Rh(COD)Cl]$_2$', '[Rhcp*Cl$_2$]$_2$', 'Pd(Opiv)$_2$']

# create matrix with desired order
matrix = df.pivot_table(index='substrate1', columns='catalyst', values='no.', fill_value=0, aggfunc='sum')
matrix = matrix.reindex(substrate_order)
matrix = matrix[catalyst_order]

# plot the heatmap with increased color saturation
sns.set(font_scale=1.2)
fig, ax = plt.subplots(figsize=(8, 6))
cmap = sns.light_palette("navy", as_cmap=True, reverse=False)
sns.heatmap(matrix, annot=True, cmap=cmap, fmt='g', linewidths=.5, cbar=False,
            cbar_kws={"label": "occurance"}, linewidth=2.5, linecolor='white', annot_kws={"fontsize": 14})

# Set background color
#ax.set_facecolor('#001F3F')  # dark blue background color

ax.set_title('substrate vs catalyst', pad=15, fontsize=14)
ax.set_xlabel('catalyst', fontsize=14)
ax.set_ylabel('substrate catagory', fontsize=14)

# rotate y-axis by 90 degrees
ax.set_yticklabels(ax.get_yticklabels(), rotation=0, fontsize=12)
ax.set_xticklabels(ax.get_xticklabels(), rotation=0, fontsize=12)

# save the heatmap as a PNG file
fig.savefig('substrate vs catalyst-4.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# create dataframe
df = pd.DataFrame({
    'substrate_1': ['S1', 'S1', 'S1', 'S1', 'S1', 'S2', 'S2', 'S3', 'S3', 'S3', 'S4', 'S5', 'S5', 'S6', 'S7', 'S7', 'S8', 'S8', 'S8', 'S9', 'S10', 'S11', 'S12', 'S13', 'S14', 'S15', 'S16'],
    'ligand': ['Ac-Gly-OH', 'For-Gly-OH', 'Boc-Ala-OH', 'Xphos', 'No-ligand', 'Ac-Gly-OH', 'No-ligand', 'Ac-Phe-OH', 'Boc-Ala-OH', 'Ac-Gly-OH', 'Ac-Gly-OH', 'Ac-Gly-OH', 'No-ligand', 'Ac-Phe-OH', 'Ac-Gly-OH', 'Ac-Val-OH', 'Ac-Gly-OH', 'For-Gly-OH', 'No-ligand', 'Ac-Gly-OH', 'Ac-Val-OH', 'Ac-Gly-OH', 'Ac-Gly-OH', 'No-ligand', 'Ac-Gly-OH', 'No-ligand', 'Ac-Gly-OH'],
    'no': [87, 30, 16, 57, 14, 60, 19, 23, 7, 6, 34, 45, 10, 58, 41, 19, 32, 23, 56, 25, 8, 55, 22, 29, 22, 21, 48]
})

# define order of substrates and reaction types
substrate_order = ['S1', 'S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8', 'S9', 'S10', 'S11', 'S12', 'S13', 'S14', 'S15', 'S16']
reaction_order = ['Ac-Gly-OH', 'For-Gly-OH', 'Ac-Phe-OH', 'Ac-Val-OH', 'Boc-Ala-OH', 'Xphos', 'No-ligand']

# create matrix with desired order
matrix = df.pivot_table(index='substrate_1', columns='ligand', values='no', fill_value=0, aggfunc='sum')
matrix = matrix.reindex(substrate_order)
matrix = matrix[reaction_order]

# plot the heatmap with increased color saturation
sns.set(font_scale=1.2)
fig, ax = plt.subplots(figsize=(8, 6))
cmap = sns.light_palette("red", as_cmap=True, reverse=False)
sns.heatmap(matrix, annot=True, cmap=cmap, fmt='g', linewidths=.5,
            cbar_kws={"label": "occurance"}, linewidth=2.5, linecolor='white', annot_kws={"fontsize": 14})

ax.set_title('substrate vs ligand', pad=15, fontsize=14)
ax.set_xlabel('ligand', fontsize=14)
ax.set_ylabel('substrate catagory', fontsize=14)

# rotate y-axis by 90 degrees
ax.set_yticklabels(ax.get_yticklabels(), rotation=0)
ax.set_xticklabels(ax.get_xticklabels(), rotation=60)
# save the heatmap as a PNG file
fig.savefig('substrate vs ligand.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# create dataframe
df = pd.DataFrame({
    'substrate_1': ['S1', 'S1', 'S1', 'S1', 'S1', 'S2', 'S2', 'S3', 'S3', 'S4', 'S4', 'S5', 'S5', 'S6', 'S6', 'S7', 'S7', 'S7', 'S8', 'S8', 'S8', 'S8', 'S8', 'S9', 'S10', 'S11', 'S11', 'S12', 'S13', 'S14', 'S15', 'S16', 'S16'],
    'oxidant': ['Ag$_2$CO$_3$', 'V$_2$O$_5$', 'AgOAc', 'No-oxidant', 'Ag$_2$SO$_4$', 'Ag$_2$CO$_3$', 'Ag$_2$SO$_4$', 'Ag$_2$CO$_3$', 'No-oxidant', 'Ag$_2$CO$_3$', 'AgOAc', 'Ag$_2$SO$_4$', 'AgOAc', 'AgOPiv', 'Ag$_2$CO$_3$', 'Cu(OAc)$_2$', 'AgOAc', 'PhI(OAc)$_2$', 'Ag$_3$PO$_4$', 'AgOAc', 'Ag$_2$CO$_3$', 'No-oxidant', 'Cu(TFA)$_2$.H$_2$O', 'AgOAc', 'Ag$_2$CO$_3$', 'AgOAc', 'PhI(OAc)$_2$', 'AgOAc', 'No-oxidant', 'AgOAc', 'V$_2$O$_5$', 'AgOAc', 'CsF'],
    'no': [87, 57, 15, 31, 14, 60, 19, 23, 13, 23, 11, 10, 45, 39, 19, 32, 20, 8, 29, 23, 23, 8, 27, 25, 8, 34, 21, 22, 29, 22, 21, 40, 8]
})

# define order of substrates and reaction types
substrate_order = ['S1', 'S2', 'S3', 'S4', 'S5', 'S6', 'S7', 'S8', 'S9', 'S10', 'S11', 'S12', 'S13', 'S14', 'S15', 'S16']
reaction_order = ['Ag$_2$CO$_3$', 'AgOAc', 'Ag$_2$SO$_4$', 'Ag$_3$PO$_4$', 'AgOPiv', 'Cu(OAc)$_2$', 'Cu(TFA)$_2$.H$_2$O', 'V$_2$O$_5$', 'PhI(OAc)$_2$', 'CsF', 'No-oxidant']

# create matrix with desired order
matrix = df.pivot_table(index='substrate_1', columns='oxidant', values='no', fill_value=0, aggfunc='sum')
matrix = matrix.reindex(substrate_order)
matrix = matrix[reaction_order]

# plot the heatmap with increased color saturation
sns.set(font_scale=1.2)
fig, ax = plt.subplots(figsize=(8, 6))
cmap = sns.light_palette("orange", as_cmap=True, reverse=False)
sns.heatmap(matrix, annot=True, cmap=cmap, fmt='g', linewidths=.5,
            cbar_kws={"label": "occurance"}, linewidth=2.5, linecolor='white', annot_kws={"fontsize": 14})

ax.set_title('substrate vs oxidant', pad=15, fontsize=14)
ax.set_xlabel('oxidant', fontsize=14)
ax.set_ylabel('substrate catagory', fontsize=14)

# rotate y-axis by 90 degrees
ax.set_yticklabels(ax.get_yticklabels(), rotation=0)
ax.set_xticklabels(ax.get_xticklabels(), rotation=60)
# save the heatmap as a PNG file
fig.savefig('substrate vs oxidant-2.png', dpi=300, bbox_inches='tight')
plt.show()
